# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Datas/clear_encoded_data.csv")
df
# Out:
#        Br   C  Cl  F   H  I  N  O  P  S
# 0       0  20   1  0  18  0  4  2  0  1
# 1       1  13   0  0  24  0  1  1  0  1
# 2       1  12   0  0  20  0  3  1  0  0
# 3       0  16   0  2  25  0  2  1  0  0
# 4       0  18   0  0  17  0  3  0  0  0
# ...    ..  ..  .. ..  .. .. .. .. .. ..
# 62082   0  17   2  0  22  0  3  2  0  0
# 62083   0  16   0  0  20  0  3  0  0  0
# 62084   0  19   0  0  30  0  2  0  0  0
# 62085   0  16   0  0  34  0  2  0  0  0
# 62086   1  14   0  0  23  0  1  3  0  0
#
# [62087 rows x 10 columns]

# %%
atom_weights ={
    "Br": 79.907,
    "C" : 12.01,
    "Cl": 35.45,
    "F": 18.99,
    "H": 1.0079,
    "I": 126.904,
    "N": 14.0068,
    "O": 15.99,
    "P": 30.97,
    "S": 32.062
}

# %%
for cols in df.columns:
    df[cols] *= atom_weights[cols]

# %%
weight_df = pd.DataFrame(df.T.sum(), columns=["weight"])
weight_df.to_csv("Datas/molecular_weights.csv", index=False)
weight_df
# Out:
#          weight
# 0      413.8614
# 1      322.2854
# 2      302.1954
# 3      299.3411
# 4      275.3347
# ...         ...
# 62082  371.2442
# 62083  254.3384
# 62084  286.4406
# 62085  254.4422
# 62086  333.2055
#
# [62087 rows x 1 columns]
