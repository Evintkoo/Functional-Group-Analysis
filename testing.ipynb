# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("250k_rndm_zinc_drugs_clean_3.csv")
df.drop("smiles", axis=1, inplace=True)
df
# Out:
#            logP       qed       SAS
# 0       5.05060  0.702012  2.084095
# 1       3.11370  0.928975  3.432004
# 2       4.96778  0.599682  2.470633
# 3       4.00022  0.690944  2.822753
# 4       3.60956  0.789027  4.035182
# ...         ...       ...       ...
# 249450  3.36790  0.745901  2.900726
# 249451  2.87430  0.799426  2.326627
# 249452  2.90054  0.878086  1.840642
# 249453  2.55624  0.852917  2.024638
# 249454  3.64990  0.370287  2.214249
#
# [249455 rows x 3 columns]

# %%
sns.pairplot(df)

# %%
sns.heatmap(abs(df.corr()), annot=True)
# Out:
# <Axes: >
